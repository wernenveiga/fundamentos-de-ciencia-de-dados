# %% [markdown]
# <a href="https://colab.research.google.com/github/wernenveiga/fundamentos-de-ci-ncia-de-dados/blob/main/Teste_de_Hip%C3%B3tese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Teste de Hipótese

# %% [markdown]
# ##Bibliotecas

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
#Arquivo

arquivo = "/content/mamalia_sleep.csv"

df_mamiferos = pd.read_csv(arquivo)

# %% [markdown]
# ##Teste de Hipótese Z

# %%
med_sono_pop = df_mamiferos['sleep_total'].mean()
despd_sono_pop = df_mamiferos['sleep_total'].std()
df_mamiferos['sleep_total'].describe()
# Out:
# count    83.000000
# mean     10.433735
# std       4.450357
# min       1.900000
# 25%       7.850000
# 50%      10.100000
# 75%      13.750000
# max      19.900000
# Name: sleep_total, dtype: float64

# %%
sono_ordem = df_mamiferos.groupby('order')['sleep_total'].mean() #Media de sonos por ordem
sono_ordem
# Out:
# order
# Afrosoricida       15.600000
# Artiodactyla        4.516667
# Carnivora          10.116667
# Cetacea             4.500000
# Chiroptera         19.800000
# Cingulata          17.750000
# Didelphimorphia    18.700000
# Diprotodontia      12.400000
# Erinaceomorpha     10.200000
# Hyracoidea          5.666667
# Lagomorpha          8.400000
# Monotremata         8.600000
# Perissodactyla      3.466667
# Pilosa             14.400000
# Primates           10.500000
# Proboscidea         3.600000
# Rodentia           12.468182
# Scandentia          8.900000
# Soricomorpha       11.100000
# Name: sleep_total, dtype: float64

# %%
is_rodentia = df_mamiferos['order'] == "Rodentia"
df_rodentia = df_mamiferos[is_rodentia]
# Out:
#                               name         genus   vore  ... awake  brainwt  bodywt
# 2                  Mountain beaver    Aplodontia  herbi  ...   9.6      NaN   1.350
# 7                     Vesper mouse       Calomys    NaN  ...  17.0      NaN   0.045
# 11                      Guinea pig         Cavis  herbi  ...  14.6  0.00550   0.728
# 13                      Chinchilla    Chinchilla  herbi  ...  11.5  0.00640   0.420
# 15       African giant pouched rat    Cricetomys   omni  ...  15.7  0.00660   1.000
# 26       Western american chipmunk      Eutamias  herbi  ...   9.1      NaN   0.071
# 38                Mongolian gerbil      Meriones  herbi  ...   9.8      NaN   0.053
# 39                  Golden hamster  Mesocricetus  herbi  ...   9.7  0.00100   0.120
# 40                           Vole       Microtus  herbi  ...  11.2      NaN   0.035
# 41                     House mouse           Mus  herbi  ...  11.5  0.00040   0.022
# ...

# %%
sono_roedores = df_rodentia['sleep_total']
med_sono_roedores = sono_roedores.mean()

# %%
##Calcular o Z
z_value = (med_sono_roedores - med_sono_pop)/ despd_sono_pop
z_value
# Out:
# 0.45714240065086326

# %%
stats.norm.cdf(z_value)
(1 - stats.norm.cdf(z_value))*100
# Out:
# 32.37843478608815
